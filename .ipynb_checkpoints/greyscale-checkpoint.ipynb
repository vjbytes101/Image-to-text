# %%
import numpy as np
from matplotlib import pyplot as plt
img = plt.imread('C:/Users/Vijay/Isaac/image/img2/5hb.jpg')
plt.imshow(img)
plt.show()
y_s,x_s,z=img.shape

# %%
def rgb2gray(rgb):

    r, g, b = rgb[:,:,0], rgb[:,:,1], rgb[:,:,2]
    gray = 0.3 * r + 0.59 * g + 0.11 * b

    return gray
img1= rgb2gray(img)
lowValY = 200
img1.max() #as this is 254.69 we approximately set it to 200
# Out:
# 254.69999999999999

# %%
l_t = img1[:h,:w]
l_t = np.asarray(l_t)
low_values_flags = l_t < lowValY  # Where values are low
l_t[low_values_flags] = 0 
plt.imshow(l_t,cmap="gray")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2ed2756632e3> in <module>()
# ----> 1 l_t = img1[:h,:w]
#       2 l_t = np.asarray(l_t)
#       3 low_values_flags = l_t < lowValY  # Where values are low
#       4 l_t[low_values_flags] = 0
#       5 plt.imshow(l_t,cmap="gray")
#
# NameError: name 'h' is not defined

# %%
l_b = img1[y_s-h:,:w]
l_b = np.asarray(l_b)
low_values_flags = l_b < lowValY  # Where values are low
l_b[low_values_flags] = 0 
plt.imshow(l_b,cmap="gray")
plt.show()

# %%
r_b = img1[y_s-h:,x_s-w:]
r_b = np.asarray(r_b)
low_values_flags = r_b < lowValY  # Where values are low
r_b[low_values_flags] = 0 
plt.imshow(r_b,cmap="gray")
plt.show()

# %%
r_t = img1[:h,x_s-w:]
r_t = np.asarray(r_t)
low_values_flags = r_t < lowValY  # Where values are low
r_t[low_values_flags] = 0 
plt.imshow(r_t,cmap="gray")
plt.show()
